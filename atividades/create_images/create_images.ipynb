# %% [markdown]
# <a href="https://colab.research.google.com/github/Jacques-Wolbeck/Processamento-Digital-Imagens-UFAL/blob/main/atividades/create_images/create_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


#(1) Create the image of a paraboloid with one axis scaled

def paraboloid(x, y, a, b, c): # hyperbolic paraboloid 
    return c*((pow(x,2)/pow(a,2)) - (pow(y,2)/pow(b,2)))

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

X, Y = np.meshgrid(x, y)
Z = paraboloid(X, Y, 1, 1, 1)

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 80, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
#(2)  Create the image of a rotated sin using rotation of coordinates.
fig = plt.figure()
ax = plt.axes(projection='3d')

x = np.linspace(-2*np.pi, 2*np.pi, 200)
y = np.linspace(-2*np.pi, 2*np.pi, 200)
tau, phase = np.meshgrid(x, y) 
amp = np.sin(tau + phase)

ax.contour3D(x, y, amp, 80, cmap='binary')
ax.set_xlabel(r'$\tau$') # tau = omega*t
ax.set_ylabel(r'$\phi$')
ax.set_zlabel('amplitude')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Text(0.5, 0, 'amplitude')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

#rotation of coordinates
# x' = x*cos(theta) + y*sin(theta)
# y' = -x*sin(theta) + y*cos(theta) 	
 
tau_rot = np.cos(0.50)*tau + np.sin(0.50)*phi 
phase_rot = -np.sin(0.50)*tau + np.cos(0.50)*phi

ax.contour3D(tau_rot, phase_rot, amp, 80, cmap='binary')

ax.set_xlabel(r'$\tau$')
ax.set_ylabel(r'$\phi$')
ax.set_zlabel('amplitude')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# Text(0.5, 0, 'amplitude')
